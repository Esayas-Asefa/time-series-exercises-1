# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
import prepare as prep
import env

# %%
df = pd.read_csv('ts_superstore.csv', index_col=0)

# %%
df.head()
# Out:
#    item  sale_amount                      sale_date  sale_id  store  \
# 0     1         13.0  Tue, 01 Jan 2013 00:00:00 GMT        1      1
# 1     1         11.0  Wed, 02 Jan 2013 00:00:00 GMT        2      1
# 2     1         14.0  Thu, 03 Jan 2013 00:00:00 GMT        3      1
# 3     1         13.0  Fri, 04 Jan 2013 00:00:00 GMT        4      1
# 4     1         10.0  Sat, 05 Jan 2013 00:00:00 GMT        5      1
#
#   item_brand  item_id                       item_name  item_price  \
# 0   Riceland        1  Riceland American Jazmine Rice        0.84
# 1   Riceland        1  Riceland American Jazmine Rice        0.84
# 2   Riceland        1  Riceland American Jazmine Rice        0.84
# 3   Riceland        1  Riceland American Jazmine Rice        0.84
# 4   Riceland        1  Riceland American Jazmine Rice        0.84
#
#     item_upc12   item_upc14           store_address   store_city  store_id  \
# 0  35200264013  35200264013  12125 Alamo Ranch Pkwy  San Antonio         1
# ...

# %%
df.shape
# Out:
# (913000, 16)

# %% [markdown]
# Convert date column to datetime format.

# %%
df.sale_date = df.sale_date.replace(' 00:00:00 GMT', '')

# %%
df.head()
# Out:
#    sale_date  item  sale_amount  sale_id  store item_brand  item_id  \
# 0 2013-01-01     1         13.0        1      1   Riceland        1
# 1 2013-01-02     1         11.0        2      1   Riceland        1
# 2 2013-01-03     1         14.0        3      1   Riceland        1
# 3 2013-01-04     1         13.0        4      1   Riceland        1
# 4 2013-01-05     1         10.0        5      1   Riceland        1
#
#                         item_name  item_price   item_upc12  ...  \
# 0  Riceland American Jazmine Rice        0.84  35200264013  ...
# 1  Riceland American Jazmine Rice        0.84  35200264013  ...
# 2  Riceland American Jazmine Rice        0.84  35200264013  ...
# 3  Riceland American Jazmine Rice        0.84  35200264013  ...
# 4  Riceland American Jazmine Rice        0.84  35200264013  ...
#
#             store_address   store_city store_id  store_state store_zipcode  \
# 0  12125 Alamo Ranch Pkwy  San Antonio        1           TX         78253
# ...

# %% [markdown]
# df.sale_date = df.sale_date.str.strip()

# %% [markdown]
# df.sale_date = pd.to_datetime(df.sale_date, format = '%a, %d %b %Y')

# %%
df.head()
# Out:
#    sale_date  item  sale_amount  sale_id  store item_brand  item_id  \
# 0 2013-01-01     1         13.0        1      1   Riceland        1
# 1 2013-01-02     1         11.0        2      1   Riceland        1
# 2 2013-01-03     1         14.0        3      1   Riceland        1
# 3 2013-01-04     1         13.0        4      1   Riceland        1
# 4 2013-01-05     1         10.0        5      1   Riceland        1
#
#                         item_name  item_price   item_upc12  ...  \
# 0  Riceland American Jazmine Rice        0.84  35200264013  ...
# 1  Riceland American Jazmine Rice        0.84  35200264013  ...
# 2  Riceland American Jazmine Rice        0.84  35200264013  ...
# 3  Riceland American Jazmine Rice        0.84  35200264013  ...
# 4  Riceland American Jazmine Rice        0.84  35200264013  ...
#
#             store_address   store_city store_id  store_state store_zipcode  \
# 0  12125 Alamo Ranch Pkwy  San Antonio        1           TX         78253
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 913000 entries, 0 to 912999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   sale_date      913000 non-null  datetime64[ns]
#  1   item           913000 non-null  int64
#  2   sale_amount    913000 non-null  float64
#  3   sale_id        913000 non-null  int64
#  4   store          913000 non-null  int64
#  5   item_brand     913000 non-null  object
#  6   item_id        913000 non-null  int64
#  7   item_name      913000 non-null  object
#  8   item_price     913000 non-null  float64
#  9   item_upc12     913000 non-null  int64
#  10  item_upc14     913000 non-null  int64
#  11  store_address  913000 non-null  object
#  12  store_city     913000 non-null  object
#  13  store_id       913000 non-null  int64
#  14  store_state    913000 non-null  object
#  15  store_zipcode  913000 non-null  int64
#  16  year           913000 non-null  int64
# ...

# %% [markdown]
# Plot the distribution of sale_amount and item_price.
#     In order to do so you need to:
#         turn the date portion into an index
#         Resample the data .resample(X).mean()
#         and then plot it

# %% [markdown]
# df.set_index('sale_date', inplace=True)

# %%
df.head()
# Out:
#    sale_date  item  sale_amount  sale_id  store item_brand  item_id  \
# 0 2013-01-01     1         13.0        1      1   Riceland        1
# 1 2013-01-02     1         11.0        2      1   Riceland        1
# 2 2013-01-03     1         14.0        3      1   Riceland        1
# 3 2013-01-04     1         13.0        4      1   Riceland        1
# 4 2013-01-05     1         10.0        5      1   Riceland        1
#
#                         item_name  item_price   item_upc12  ...  \
# 0  Riceland American Jazmine Rice        0.84  35200264013  ...
# 1  Riceland American Jazmine Rice        0.84  35200264013  ...
# 2  Riceland American Jazmine Rice        0.84  35200264013  ...
# 3  Riceland American Jazmine Rice        0.84  35200264013  ...
# 4  Riceland American Jazmine Rice        0.84  35200264013  ...
#
#             store_address   store_city store_id  store_state store_zipcode  \
# 0  12125 Alamo Ranch Pkwy  San Antonio        1           TX         78253
# ...

# %% [markdown]
# df_resampled = df.resample('W').mean()

# %% [markdown]
# plt.plot(df_resampled.index, df_resampled['item_price'], label='Item Price')
# plt.plot(df_resampled.index, df_resampled['sale_amount'], label='Sale Amount')
#
# plt.title('sale amount and item price over time')
# plt.legend()
# plt.show()

# %% [markdown]
# Set the index to be the datetime variable.
# Done

# %% [markdown]
# Add a 'month' and 'day of week' column to your dataframe.

# %% [markdown]
# df.reset_index('sale_date', inplace=True)

# %% [markdown]
# df['year'] = df.sale_date.dt.year
# df['dayofweek'] = df.sale_date.dt.day_of_week

# %%
df.head()
# Out:
#    sale_date  item  sale_amount  sale_id  store item_brand  item_id  \
# 0 2013-01-01     1         13.0        1      1   Riceland        1
# 1 2013-01-02     1         11.0        2      1   Riceland        1
# 2 2013-01-03     1         14.0        3      1   Riceland        1
# 3 2013-01-04     1         13.0        4      1   Riceland        1
# 4 2013-01-05     1         10.0        5      1   Riceland        1
#
#                         item_name  item_price   item_upc12  ...  \
# 0  Riceland American Jazmine Rice        0.84  35200264013  ...
# 1  Riceland American Jazmine Rice        0.84  35200264013  ...
# 2  Riceland American Jazmine Rice        0.84  35200264013  ...
# 3  Riceland American Jazmine Rice        0.84  35200264013  ...
# 4  Riceland American Jazmine Rice        0.84  35200264013  ...
#
#             store_address   store_city store_id  store_state store_zipcode  \
# 0  12125 Alamo Ranch Pkwy  San Antonio        1           TX         78253
# ...

# %% [markdown]
# Add a column to your dataframe, sales_total, which is a derived from sale_amount (total items) and item_price.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 913000 entries, 0 to 912999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   sale_date      913000 non-null  datetime64[ns]
#  1   item           913000 non-null  int64
#  2   sale_amount    913000 non-null  float64
#  3   sale_id        913000 non-null  int64
#  4   store          913000 non-null  int64
#  5   item_brand     913000 non-null  object
#  6   item_id        913000 non-null  int64
#  7   item_name      913000 non-null  object
#  8   item_price     913000 non-null  float64
#  9   item_upc12     913000 non-null  int64
#  10  item_upc14     913000 non-null  int64
#  11  store_address  913000 non-null  object
#  12  store_city     913000 non-null  object
#  13  store_id       913000 non-null  int64
#  14  store_state    913000 non-null  object
#  15  store_zipcode  913000 non-null  int64
#  16  year           913000 non-null  int64
# ...

# %% [markdown]
# df['sales_total'] = df.sale_amount * df.item_price

# %%
df.head()
# Out:
#    sale_date  item  sale_amount  sale_id  store item_brand  item_id  \
# 0 2013-01-01     1         13.0        1      1   Riceland        1
# 1 2013-01-02     1         11.0        2      1   Riceland        1
# 2 2013-01-03     1         14.0        3      1   Riceland        1
# 3 2013-01-04     1         13.0        4      1   Riceland        1
# 4 2013-01-05     1         10.0        5      1   Riceland        1
#
#                         item_name  item_price   item_upc12  ...  \
# 0  Riceland American Jazmine Rice        0.84  35200264013  ...
# 1  Riceland American Jazmine Rice        0.84  35200264013  ...
# 2  Riceland American Jazmine Rice        0.84  35200264013  ...
# 3  Riceland American Jazmine Rice        0.84  35200264013  ...
# 4  Riceland American Jazmine Rice        0.84  35200264013  ...
#
#             store_address   store_city store_id  store_state store_zipcode  \
# 0  12125 Alamo Ranch Pkwy  San Antonio        1           TX         78253
# ...

# %% [markdown]
# Make sure all the work that you have done above is reproducible.

# %% [markdown]
# That is, you should put the code above into separate functions and be able to re-run the functions and get the same results.

# %% [markdown]
# def prep_sales(df):
#     df.sale_date = df.sale_date.str.replace('00:00:00 GMT', '')
#     df.sale_date = df.sale_date.str.strip()
#     df.sale_date = pd.to_datetime(df.sale_date, format = '%a, %d %b %Y')
#     df.set_index('sale_date', inplace=True)
#     df.reset_index('sale_date', inplace=True)
#     df['year'] = df.sale_date.dt.year
#     df['dayofweek'] = df.sale_date.dt.day_of_week
#     df['sales_total'] = df.sale_amount * df.item_price
#     #add seasons
#     #if null count per column is less than 5 percent of total, drop
#     # if null count per column is greater than 5 percent replace with mean for that column
#
#     return df

# %% [markdown]
# Using the OPS data acquired in the Acquire exercises
# opsd_germany_daily.csv,

# %%
df['month'] = df.sale_date.dt.month

# %%
df.head()
# Out:
#    sale_date  item  sale_amount  sale_id  store item_brand  item_id  \
# 0 2013-01-01     1         13.0        1      1   Riceland        1
# 1 2013-01-02     1         11.0        2      1   Riceland        1
# 2 2013-01-03     1         14.0        3      1   Riceland        1
# 3 2013-01-04     1         13.0        4      1   Riceland        1
# 4 2013-01-05     1         10.0        5      1   Riceland        1
#
#                         item_name  item_price   item_upc12  ...  \
# 0  Riceland American Jazmine Rice        0.84  35200264013  ...
# 1  Riceland American Jazmine Rice        0.84  35200264013  ...
# 2  Riceland American Jazmine Rice        0.84  35200264013  ...
# 3  Riceland American Jazmine Rice        0.84  35200264013  ...
# 4  Riceland American Jazmine Rice        0.84  35200264013  ...
#
#             store_address   store_city store_id  store_state store_zipcode  \
# 0  12125 Alamo Ranch Pkwy  San Antonio        1           TX         78253
# ...

# %%
df = pd.read_csv("https://raw.githubusercontent.com/jenfly/opsd/master/opsd_germany_daily.csv")

# %%
df.head()
# Out:
#          Date  Consumption  Wind  Solar  Wind+Solar
# 0  2006-01-01     1069.184   NaN    NaN         NaN
# 1  2006-01-02     1380.521   NaN    NaN         NaN
# 2  2006-01-03     1442.533   NaN    NaN         NaN
# 3  2006-01-04     1457.217   NaN    NaN         NaN
# 4  2006-01-05     1477.131   NaN    NaN         NaN

# %% [markdown]
# Convert date column to datetime format.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4383 entries, 0 to 4382
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         4383 non-null   object
#  1   Consumption  4383 non-null   float64
#  2   Wind         2920 non-null   float64
#  3   Solar        2188 non-null   float64
#  4   Wind+Solar   2187 non-null   float64
# dtypes: float64(4), object(1)
# memory usage: 171.3+ KB

# %% [markdown]
# Plot the distribution of each of your variables.

# %% [markdown]
# Set the index to be the datetime variable.

# %% [markdown]
# Add a month and a year column to your dataframe.

# %% [markdown]
# Fill any missing values.

# %% [markdown]
# Make sure all the work that you have done above is reproducible.

# %% [markdown]
# That is, you should put the code above into separate functions and be able to re-run the functions and get the same results.
